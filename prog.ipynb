# %%
print("Humpty Dumpty sat on a wall \n Humpty Dumpty had a great fall")
# Out:
# Humpty Dumpty sat on a wall
#  Humpty Dumpty had a great fall

# %%
print("Humpty Dumpty sat on a wall" ," Humpty Dumpty had", " a great fall")
# Out:
# Humpty Dumpty sat on a wall  Humpty Dumpty had  a great fall

# %%
print("Humpty Dumpty sat on a wall" ," Humpty Dumpty had", end="")
print(" a great fall")
# Out:
# Humpty Dumpty sat on a wall  Humpty Dumpty had a great fall

# %%
print("Humpty Dumpty sat on a wall" ," Humpty Dumpty had", sep="-")
print(" a great fall")
# Out:
# Humpty Dumpty sat on a wall- Humpty Dumpty had
#  a great fall

# %%
print("Humpty Dumpty"," sat on a wall" , sep="-", end="\n")
print("Humpty Dumpty had",  "a great", " fall", sep=":", end="")
# Out:
# Humpty Dumpty- sat on a wall
# Humpty Dumpty had:a great: fall
